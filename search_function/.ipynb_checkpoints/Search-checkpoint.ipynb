# %%
import pandas as pd
import numpy as np
import time
from tabulate import tabulate

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df = df.iloc[20:].reset_index(drop=True)
df.head()
# Out:
#   show_id     type                                title           director  \
# 0     s21    Movie                 ​​Kuch Bheege Alfaaz               Onir
# 1     s22    Movie                         ​Goli Soda 2       Vijay Milton
# 2     s23    Movie                   ​Maj Rati ​​Keteki  Santwana Bardoloi
# 3     s24    Movie                          ​Mayurakshi        Atanu Ghosh
# 4     s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac                NaN
#
#                                                 cast country  \
# 0  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...   India
# 1  Samuthirakani, Bharath Seeni, Vinoth, Esakki B...   India
# 2  Adil Hussain, Shakil Imtiaz, Mahendra Rabha, S...   India
# 3  Soumitra Chatterjee, Prasenjit Chatterjee, Ind...   India
# 4  Bryson Baugus, Emily Neves, Blake Shepard, Pat...   Japan
#
#            date_added  release_year rating   duration  \
# 0   September 1, 2018          2018  TV-14    110 min
# 1  September 15, 2018          2018  TV-14    128 min
# 2  September 15, 2018          2017  TV-14    117 min
# 3  September 15, 2018          2017  TV-14    100 min
# 4    January 23, 2020          2020  TV-14  2 Seasons
#
#                                           listed_in  \
# 0  Dramas, Independent Movies, International Movies
# 1  Action & Adventure, Dramas, International Movies
# 2                      Dramas, International Movies
# 3                      Dramas, International Movies
# 4              Anime Series, International TV Shows
#
#                                          description
# 0  After accidentally connecting over the Interne...
# 1  A taxi driver, a gangster and an athlete strug...
# 2  A successful writer returns to the town that l...
# 3  When a middle-aged divorcee returns to Kolkata...
# 4  Seiya and the Knights of the Zodiac rise again...

# %%
df["date_added"] = pd.to_datetime(df['date_added'])
df['year'] = df['date_added'].dt.year
df['month'] = df['date_added'].dt.month
df['day'] = df['date_added'].dt.day
#df['directors'] = df['director'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
#df['categories'] = df['listed_in'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
#df['actors'] = df['cast'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])
#df['countries'] = df['country'].apply(lambda l: [] if pd.isna(l) else [i.strip() for i in l.split(",")])

# %%
search_df = df.drop(["show_id", "duration", "year", "month", "day"], axis=1)
search_df.head()
# Out:
#       type                                title           director  \
# 0    Movie                 ​​Kuch Bheege Alfaaz               Onir
# 1    Movie                         ​Goli Soda 2       Vijay Milton
# 2    Movie                   ​Maj Rati ​​Keteki  Santwana Bardoloi
# 3    Movie                          ​Mayurakshi        Atanu Ghosh
# 4  TV Show  ​SAINT SEIYA: Knights of the Zodiac                NaN
#
#                                                 cast country date_added  \
# 0  Geetanjali Thapa, Zain Khan Durrani, Shray Rai...   India 2018-09-01
# 1  Samuthirakani, Bharath Seeni, Vinoth, Esakki B...   India 2018-09-15
# 2  Adil Hussain, Shakil Imtiaz, Mahendra Rabha, S...   India 2018-09-15
# 3  Soumitra Chatterjee, Prasenjit Chatterjee, Ind...   India 2018-09-15
# 4  Bryson Baugus, Emily Neves, Blake Shepard, Pat...   Japan 2020-01-23
#
#    release_year rating                                         listed_in  \
# 0          2018  TV-14  Dramas, Independent Movies, International Movies
# 1          2018  TV-14  Action & Adventure, Dramas, International Movies
# 2          2017  TV-14                      Dramas, International Movies
# 3          2017  TV-14                      Dramas, International Movies
# 4          2020  TV-14              Anime Series, International TV Shows
#
#                                          description
# 0  After accidentally connecting over the Interne...
# 1  A taxi driver, a gangster and an athlete strug...
# 2  A successful writer returns to the town that l...
# 3  When a middle-aged divorcee returns to Kolkata...
# 4  Seiya and the Knights of the Zodiac rise again...

# %%
titles_df = search_df.drop(["type", "director","cast","country","release_year","listed_in"], axis=1) #["date_added"] #"type", "date_added", "director"
titles_df.head()
# Out:
#                                  title date_added rating  \
# 0                 ​​Kuch Bheege Alfaaz 2018-09-01  TV-14
# 1                         ​Goli Soda 2 2018-09-15  TV-14
# 2                   ​Maj Rati ​​Keteki 2018-09-15  TV-14
# 3                          ​Mayurakshi 2018-09-15  TV-14
# 4  ​SAINT SEIYA: Knights of the Zodiac 2020-01-23  TV-14
#
#                                          description
# 0  After accidentally connecting over the Interne...
# 1  A taxi driver, a gangster and an athlete strug...
# 2  A successful writer returns to the town that l...
# 3  When a middle-aged divorcee returns to Kolkata...
# 4  Seiya and the Knights of the Zodiac rise again...

# %%
test = search_df["title"].values

# %%
cv = make_pipeline(
    CountVectorizer(
        ngram_range=(3, 3),
        analyzer="char_wb",
    ),
    Normalizer()
)

# %%
cv = cv.fit(test)

# %%
X = cv.transform(test)

# %%
def search(term):
    
    X_term = cv.transform([term])
    simular = cosine_similarity(X_term, X)
    
    final_list = []
    
    idxmax = np.argmax(simular[0])
           
    sim_scores = list(enumerate(simular[0]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[0:5]
    movie_indices = [i[0] for i in sim_scores]
    
    return titles_df.iloc[movie_indices].reset_index(drop=True)

# %%
(search("transformers"))
# Out:
#                        title date_added rating  \
# 0                Transformer 2019-02-20  TV-MA
# 1         Transformers Prime 2018-09-08  TV-Y7
# 2   Transformers: Cyberverse 2020-09-07  TV-Y7
# 3                  Transfers 2018-11-08  TV-MA
# 4  Transformers: Rescue Bots 2018-09-19  TV-Y7
#
#                                          description
# 0  Powerlifter Matt Kroczaleski faced his greates...
# 1  With the help of three human allies, the Autob...
# 2  Optimus Prime and the AllSpark are missing – a...
# 3  After a boating accident, woodworker and famil...
# 4  Follow the adventure of four young transformer...
